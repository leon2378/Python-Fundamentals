# %% [markdown]
# ### Bytes

# %%
bytes(4)
# Out:
# b'\x00\x00\x00\x00'

# %%
smilleyBytes = bytes('😊', 'utf-8')
smilleyBytes
# Out:
# b'\xf0\x9f\x98\x8a'

# %%
smilleyBytes.decode('utf-8')
# Out:
# '😊'

# %%
smilleyBytes = bytearray('😊', 'utf-8')

# %%
smilleyBytes
# Out:
# bytearray(b'\xf0\x9f\x98\x8a')

# %%
smilleyBytes[3] = int('85', 16)

# %%
smilleyBytes.decode('utf-8')
# Out:
# '😅'
